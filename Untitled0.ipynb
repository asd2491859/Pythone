# %%
print("Hello Mydeargreateacher")
# Out:
# Hello Mydeargreateacher

# %% [markdown]
# # 受難日第一天2019/9/23程式超簡單

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("      *    ")
print("     ***    ")
print("    *****    ")
print("   *********    ")
print("  ***********    ")
print(" **************    ")
print("****************    ")
